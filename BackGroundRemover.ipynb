# %% [markdown]
# <a href="https://colab.research.google.com/github/SharvinKumarArumugam/Githubproject/blob/main/BackGroundRemover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rembg
from rembg import remove
from PIL import Image

input_path = '/content/SharvinPic.jpg'
output_path = 'output.png'

input = Image.open(input_path)
output = remove(input)
output.save(output_path)

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt

# %%
def compare(input_path,output_path):
    fig, axes = plt.subplots(1, 2)
    axes[0].imshow(plt.imread(input_path))
    axes[0].set_title("Input Image")
    axes[1].imshow(plt.imread(output_path))
    axes[1].set_title("Output Image")
    plt.show()

compare(input_path,output_path)

# %%
display(output)
# Out:
# <PIL.Image.Image image mode=RGBA size=768x1024>

# %% [markdown]
# # New Section
